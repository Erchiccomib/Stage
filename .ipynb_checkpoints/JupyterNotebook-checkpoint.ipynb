# %% [markdown]
# # <center> Implementazione degli agloritmi di clustering su dataset di cartelle cliniche</center>
# ## <center> Introduzione </center>
# Prima di iniziare con l'implementazione, ho voluto eseguire un'attenta analisi del dataset delle cartelle cliniche, così da comprendere effettivamente la struttura del dataset e dunque capire se eseguire una pre-elaborazione dei dati o meno. Infatti, nel dataset *"10_7717_peerj_5665_dataYM2018_neuroblastoma"* si ha una struttura differente dei dati rispetto agli altri dataset, facendo notare che presenta dati di tipo sia *float64* che *object*, mentre gli altri dataset contengono solo dati numerici di tipo *float64* e *int64*, permettendo un'implementazione più semplice degli algoritmi di clustering come k-means che richiede valori solo numerici per l'elaborazione. Di seguito riporto la visualizzazione delle colonne presenti nei dataset:

# %%
import pandas as pd

print("Struttura del dataset '10_7717_peerj_5665_dataYM2018_neuroblastoma'")
dataset = pd.read_csv('C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\10_7717_peerj_5665_dataYM2018_neuroblastoma.csv')
print(dataset.info())

print("Struttura del dataset 'journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED'")
dataset2 = pd.read_csv('C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED.csv')
print(dataset2.info())

print("Struttura del dataset 'journal.pone.0158570_S2File_depression_heart_failure'")
dataset2 = pd.read_csv('C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\journal.pone.0158570_S2File_depression_heart_failure.csv')
print(dataset2.info())

print("Struttura del dataset 'journal.pone.0175818_S1Dataset_Spain_cardiac_arrest_EDITED'")
dataset2 = pd.read_csv('C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\journal.pone.0175818_S1Dataset_Spain_cardiac_arrest_EDITED..csv')
print(dataset2.info())

print("Struttura del dataset 'Takashi2019_diabetes_type1_dataset_preprocessed'")
dataset2 = pd.read_csv('C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\Takashi2019_diabetes_type1_dataset_preprocessed.csv')
print(dataset2.info())
# Out:
# Struttura del dataset '10_7717_peerj_5665_dataYM2018_neuroblastoma'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   169 non-null    float64
#  1   sex                                   170 non-null    object
#  2   site                                  172 non-null    object
#  3   stage                                 169 non-null    float64
#  4   risk                                  170 non-null    object
#  5   time_months                           170 non-null    object
#  6   autologous_stem_cell_transplantation  171 non-null    object
#  7   radiation                             171 non-null    object
#  8   degree_of_differentiation             171 non-null    object
#  9   UH_or_FH                              171 non-null    object
# ...

# %% [markdown]
# ## <center> __Implementazione sui dataset__ </center>
# Di seguito riporto l'implementazione degli algoritmi di clustering su tutti i dataset:

# %%
from sklearn.cluster import DBSCAN, KMeans, SpectralClustering, AgglomerativeClustering, Birch, MeanShift
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score, pairwise_distances_argmin_min
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time

dataset_path = 'C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED.csv'
dataset = pd.read_csv(dataset_path)
dataset = dataset.dropna()
algorithm = 'mean-shift'

scaler = MinMaxScaler()#Utilizzo MinMaxScaler per normalizzare i dati
    
if '10_7717_peerj_5665_dataYM2018_neuroblastoma' in dataset_path:
    features_ = dataset.drop(columns=['time_months', 'outcome'])#Escludo outcome perchè pongo il clustering sui valori di base dunque su nessun valore 'finale', mentre per time_months ho deciso di escluderlo perchè non è facilmente interpretabile e ha una distribuzione troppo elevata
    #Inizializzo l'encoder per trasformare le colonne categoriali
    encoder = LabelEncoder()
    #Eseguo la trasformazione, ottenendo prima tutte le colonne categoriali e poi mediante l'encoder eseguo la trasformazione
    for col in features_.select_dtypes(include=['object']).columns:
        features_[col] = encoder.fit_transform(features_[col])
    
    if 'k-means' in algorithm:
        clusters=3 #Indica il numero di cluster
    elif 'birch' in algorithm:
        clusters=3 #Indica il numero di cluster
        t= 0.2 #Indica il threshold
    elif 'dbscan' in algorithm:
        e = 0.5 #Indica eps
    elif 'agglomerative' in algorithm:
        clusters=4 #Indica il numero di cluster
        link = 'average' #Indica linkage
        aff = 'manhattan' #Indica affinity
    elif 'spectral' in algorithm:
        clusters = 3 #Indica il numero di cluster
        aff = 'rbf' #Indica affinity
        gam = 10 #Indica gamma
        neighbors = 0 #Indica n_neighbors
    elif 'mean-shift' in algorithm:
        band = 1 #Indica bandwidth
        seeding = False

elif 'journal.pone.0158570_S2File_depression_heart_failure' in dataset_path:
    features_ = dataset.drop(columns=['id'])
    scaler = StandardScaler() #Utilizzo StandardScaler per normalizzare i dati

    if 'k-means' in algorithm:
        clusters=3 #Indica il numero di cluster
    elif 'birch' in algorithm:
        clusters=None #Indica il numero di cluster
        t= 1.4 #Indica il threshold
    elif 'dbscan' in algorithm:
        e = 0.9 #Indica eps
    elif 'agglomerative' in algorithm:
        clusters=3 #Indica il numero di cluster
        link = 'ward' #Indica linkage
        aff = 'euclidean'
    elif 'spectral' in algorithm:
        clusters = 3 #Indica il numero di cluster
        aff = 'nearest_neighbors' #Indica affinity
        gam = 0 #Indica gamma
        neighbors = 40
    elif 'mean-shift' in algorithm:
        band = 1.5 #Indica bandwidth
        seeding = True

elif 'journal.pone.0175818_S1Dataset_Spain_cardiac_arrest_EDITED.' in dataset_path:
    features_ = dataset

    if 'k-means' in algorithm:
        clusters=4 #Indica il numero di cluster
    elif 'birch' in algorithm:
        clusters=None #Indica il numero di cluster
        t= 0.5 #Indica il threshold
    elif 'dbscan' in algorithm:
        e = 0.3 #Indica eps
    elif 'agglomerative' in algorithm:
        clusters=4 #Indica il numero di cluster
        link = 'ward' #Indica linkage
        aff = 'euclidean'
    elif 'spectral' in algorithm:
        clusters = 4 #Indica il numero di cluster
        aff = 'nearest_neighbors' #Indica affinity
        gam = 0 #Indica gamma
        neighbors = 130
    elif 'mean-shift' in algorithm:
        band = 0.45  #Indica bandwidth
        seeding = False #Indica bin_seeding

elif 'journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED' in dataset_path:
    features_ = dataset

    if 'k-means' in algorithm:
        clusters=4 #Indica il numero di cluster
    elif 'birch' in algorithm:
        clusters=None #Indica il numero di cluster
        t= 0.3 #Indica il threshold
    elif 'dbscan' in algorithm:
        e = 0.5 #Indica eps
    elif 'agglomerative' in algorithm:
        clusters=4 #Indica il numero di cluster
        link = 'ward' #Indica linkage
        aff = 'euclidean'
    elif 'spectral' in algorithm:
        clusters = 4 #Indica il numero di cluster
        aff = 'rbf' #Indica affinity
        gam =  35#Indica gamma
        neighbors = 0
    elif 'mean-shift' in algorithm:
        band = None  #Indica bandwidth
        seeding = True #Indica bin_seeding

elif 'Takashi2019_diabetes_type1_dataset_preprocessed' in dataset_path:
    features_ = dataset

    if 'k-means' in algorithm:
        clusters=3 #Indica il numero di cluster
    elif 'birch' in algorithm:
        clusters=None #Indica il numero di cluster
        t= 0.52 #Indica il threshold
    elif 'dbscan' in algorithm:
        e = 0.3 #Indica eps
    elif 'agglomerative' in algorithm:
        clusters=3 #Indica il numero di cluster
        link = 'ward' #Indica linkage
        aff = 'euclidean'
    elif 'spectral' in algorithm:
        clusters = 3 #Indica il numero di cluster
        aff = 'rbf' #Indica affinity
        gam = 30 #Indica gamma
        neighbors = 0 #Indica n_neighbors
    elif 'mean-shift' in algorithm:
        band = 1.35  #Indica bandwidth
        seeding = False #Indica bin_seeding

scaler_feauter = scaler.fit_transform(features_) #Normalizzo i dati

if(dataset_path == "C:\\Users\\fncba\\OneDrive\Documenti\\Stage\\Cartelle cliniche\\Takashi2019_diabetes_type1_dataset_preprocessed.csv" and algorithm=="mean-shift"):
    pca = PCA() #Non imposto n_comonents poichè l'algortimo richiede la struttura originale dei dati per funzionare correttamente 
else:
    pca = PCA(n_components=2) #Setto PCA per ridurre la dimensionalità dei dati così da ottenere una migliora rappresentazione, setto n_components=2 per indicare le componenti da mantenere dopo la riduzione
features = pca.fit_transform(scaler_feauter) #trasformo la dimensione dei dati
    
if 'k-means' in algorithm:
    start_time = time.time()
    K= range(2,10) #Setto il range di cluster da formare tramite k-means

    #Utilizzo la tecnica del gomito per comprendere quanti cluster formare
    inertia = []
    for k in K: #Inizio un ciclo in cui per ogni k in K eseguo k-means con k cluster e salvo l'inertia (somma delle sitanze quadratiche tra ogni punto del cluster ed il centroide) per comprendere con quale k è più efficiente
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(features)
        inertia.append(kmeans.inertia_)
        labelss = kmeans.labels_


    kmenas = KMeans(n_clusters=clusters, random_state=42 )
    kmenas.fit(features) #Addestro il modello
    labels = kmenas.labels_ #Ottengo le labels

    end_time = time.time()
    
    features_['Cluster'] = labels #Creo una nuova colonna 'Cluster' in cui indico a quale cluster è stato associato ogni elemento

    # Conto il numero di outlier presenti nel clustering
    centroids = kmeans.cluster_centers_ #Ottengo i centroidi

    closest,distanze = pairwise_distances_argmin_min(features, centroids) #Calcolo la distanza e le salvo nell'array distanze. Inoltre, closest è l'array che contiene il centroide più vicino per un determinato punto

    soglia = np.percentile(distanze, 95) #Uso il 95-esimo quartile delle distanze come soglia

    outliers = np.where(distanze > soglia)[0] #Ottengo dalla tupla solo le distanze che sono maggiori della soglia

    outliers_number = len(outliers) #Conto il numero di errori

    #Stampo il numero di outlier
    print(f"Numero di outlier: {outliers_number}")
    #Rappresento a video la curvatura dell'inerzia per ogni k testato su k-means
    plt.figure(figsize=(10,6))
    plt.plot(K, inertia, 'bx-')
    plt.xlabel('Numeri di cluster')
    plt.ylabel('Inertia')
    plt.title('Tecnica del Gomito')
    plt.grid(True)
    plt.show()

    #Mostro il cluster ottenuto
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(features[:, 0], features[:, 1], c=labels, cmap='viridis')
    centroids = kmenas.cluster_centers_ #Ottengo i centroidi dei cluster per mostrarli di rosso tramite delle X 
   
    plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='X', label='Centroids')
    plt.title('K-means (k=3)')
    plt.xlabel('Component 1 PCA')#Rappresenta quanto il valore di ogni punto della componente 1 di PCA si discosta dalla media dei valori
    plt.ylabel('Component 2 PCA')
    plt.legend()
    plt.colorbar(scatter, label='Cluster Label')
    plt.grid(True)
    plt.show()

elif 'spectral' in algorithm:
    start_time = time.time()
    inertia=[]
    K=range(2,10)

    for k in K:
        spectral = SpectralClustering(n_clusters=k, affinity=aff, random_state=42)
        spectral.fit(features)
        labels = spectral.labels_
        centroids = np.array([features[labels == i].mean(axis=0) for i in range(k)])

        # Calcolo della "inerzia" come somma delle distanze quadrate dai centroidi
        closest, distances = pairwise_distances_argmin_min(features, centroids)
        inertia_ = np.sum(distances ** 2)
        inertia.append(inertia_)

    spectral = SpectralClustering(n_clusters=clusters, affinity=aff, gamma=gam, random_state=42, n_neighbors= neighbors)
    spectral.fit(features)

    end_time = time.time()

    labels = spectral.labels_
    features_['Cluster'] = labels


    # Conto il numero di outlier presenti nel clustering
    centroids = np.array([features[labels == i].mean(axis=0) for i in np.unique(labels)]) #Ottengo i centroidi manualmente tramite la media dei punti presenti in essi

    closest,distanze = pairwise_distances_argmin_min(features, centroids) #Calcolo la distanza e le salvo nell'array distanze. Inoltre, closest è l'array che contiene il centroide più vicino per un determinato punto

    soglia = np.percentile(distanze, 95) #Uso il 95-esimo quartile delle distanze come soglia

    outliers = np.where(distanze > soglia)[0] #Ottengo dalla tupla solo le distanze che sono maggiori della soglia

    outliers_number = len(outliers) #Conto il numero di errori

    #Stampo il numero di outlier
    print(f"Numero di outlier: {outliers_number}")
    #Rappresento a video la curvatura dell'inerzia per ogni k testato su spectral
    plt.figure(figsize=(10,6))
    plt.plot(K, inertia, 'bx-')
    plt.xlabel('Numeri di cluster')
    plt.ylabel('Inertia')
    plt.title('Gomito')
    plt.grid(True)
    plt.show()

    #Rappresento a video i cluster ottenuti
    plt.figure(figsize=(12,8))
    plt.scatter(features[:,0], features[:,1], c=labels, cmap='viridis')
    plt.xlabel("Component 1 PCA")
    plt.ylabel("Component 2 PCA")
    plt.grid(True)
    plt.title("Spectral Clustering")
    plt.show()

elif 'birch' in algorithm:
    start_time = time.time()
    birch = Birch(threshold=t, n_clusters=clusters) #Ho provato diversi valori per branching_factor ma non cambia nulla, mentre per threshold ho notato che impostandolo a 0.2 si ha un miglior clustering. Inoltre ho settato n_cluster=3 (default) poichè settato a None vengono generati 18 cluster
    birch.fit(features)

    end_time=time.time()
    
    labels = birch.labels_
    features_['Cluster'] = labels

    # Conto il numero di outlier presenti nel clustering
    centroids = birch.subcluster_centers_ #Ottengo i centroidi

    closest,distanze = pairwise_distances_argmin_min(features, centroids) #Calcolo la distanza e le salvo nell'array distanze. Inoltre, closest è l'array che contiene il centroide più vicino per un determinato punto

    soglia = np.percentile(distanze, 95) #Uso il 95-esimo quartile delle distanze come soglia

    outliers = np.where(distanze > soglia)[0] #Ottengo dalla tupla solo le distanze che sono maggiori della soglia

    outliers_number = len(outliers) #Conto il numero di errori

    #Stampo il numero di outlier
    print(f"Numero di outlier: {outliers_number}")

    plt.figure(figsize=(12,8))
    plt.scatter(features[:,0], features[:,1], c=labels, cmap='viridis')
    plt.title("BIRCH Clustering")
    plt.xlabel("Component 1 PCA")
    plt.ylabel("Component 2 PCA")
    plt.grid(True)
    plt.show()

elif 'dbscan' in algorithm:
    start_time = time.time()
    dbscan = DBSCAN(eps=e) 
    dbscan.fit(features)

    end_time = time.time()
   
    labels = dbscan.labels_

    num = np.sum(labels==-1)
    features_['Cluster'] = labels

    print(f"Numero errori:{num}")

    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(features[:, 0], features[:, 1], c=labels, cmap='viridis', s=50, alpha=0.6)
    plt.title('DBSCAN Clustering')
    plt.xlabel('Component 1 PCA')
    plt.ylabel('Component 2 PCA')
    plt.colorbar(scatter, label='Cluster Label')
    plt.grid(True)
    plt.show()

elif 'agglomerative' in algorithm:
    start_time = time.time()

    #specifico il criterio utilizzato per unire i cluster durante il processo di clustering gerarchico e salvo il collegamento in Z
    Z = linkage(features, link)

    #Eseguo il cluster con k=4
    agglomerative = AgglomerativeClustering(n_clusters=clusters, linkage=link, affinity=aff)
    agglomerative.fit(features)

    end_time = time.time()

    labels= agglomerative.labels_

    features_['Cluster'] = labels

    # Conto il numero di outlier presenti nel clustering

    centroids = np.array([features[labels == i].mean(axis=0) for i in np.unique(labels)]) #Calcolo manualmente i centroidi come la media dei punti presenti in esso

    closest,distanze = pairwise_distances_argmin_min(features, centroids) #Calcolo la distanza e le salvo nell'array distanze. Inoltre, closest è l'array che contiene il centroide più vicino per un determinato punto

    soglia = np.percentile(distanze, 95) #Uso il 95-esimo quartile delle distanze come soglia

    outliers = np.where(distanze > soglia)[0] #Ottengo dalla tupla solo le distanze che sono maggiori della soglia

    outliers_number = len(outliers) #Conto il numero di errori

    #Stampo il numero di outlier
    print(f"Numero di outlier: {outliers_number}")

    #Mostro a video il dendrogramma per comprendere il numero di cluster da formare (k=4)
    plt.figure(figsize=(10,7))
    dendrogram(Z)
    plt.title('Dendrogramma')
    plt.xlabel('Cluster')
    plt.ylabel('Distance')
    plt.show()

    #Mostro il clustering ottenuto
    plt.figure(figsize=(12,8))
    plt.scatter(features[:,0], features[:,1], c=labels, cmap='viridis')
    plt.title("Agglomerative Clustering")
    plt.xlabel("Component 1 PCA")
    plt.ylabel("Component 2 PCA")
    plt.grid(True)
    plt.show()

elif 'mean-shift' in algorithm:
    start_time = time.time()

    mean = MeanShift(bandwidth=band, bin_seeding= seeding)
    mean.fit(features)

    end_time = time.time()

    labels = mean.labels_
    features_['Cluster'] = labels

    # Conto il numero di outlier presenti nel clustering
    centroids = mean.cluster_centers_ #Ottengo i centroidi

    closest,distanze = pairwise_distances_argmin_min(features, centroids) #Calcolo la distanza e le salvo nell'array distanze. Inoltre, closest è l'array che contiene il centroide più vicino per un determinato punto

    soglia = np.percentile(distanze, 95) #Uso il 95-esimo quartile delle distanze come soglia

    outliers = np.where(distanze > 3)[0] #Ottengo dalla tupla solo le distanze che sono maggiori della soglia

    outliers_number = len(outliers) #Conto il numero di errori

    #Stampo il numero di outlier
    print(f"Numero di outlier: {outliers_number}")

    plt.figure(figsize=(12,8))
    plt.scatter(features[:,0], features[:,1], c=labels, cmap='viridis')
    plt.xlabel("Component 1 PCA")
    plt.ylabel("Component 2 PCA")
    plt.grid(True)
    plt.title("Mean-Shift Clustering")
    plt.show()

#Calcolo e stampo a video il valore delle metriche di valutazione
score_silhouette = silhouette_score(features, labels)
print(f'Punteggio Silhouette: {score_silhouette}')

score_calinski = calinski_harabasz_score(features, labels)
print(f'Punteggio Calinski: {score_calinski} ')

score_davies = davies_bouldin_score(features, labels)
print(f'Punteggio Davies: {score_davies}')
    
#Calcolo delle statistiche descrittive per ciascun cluster così da comprendere la differenza presente tra i cluster
cluster_summary = features_.groupby('Cluster').mean()

# Heatmap delle medie delle caratteristiche nei diversi cluster
plt.figure(figsize=(12, 8))
sns.heatmap(cluster_summary.T, annot=True, cmap='viridis')
plt.title('Heatmap')
plt.xlabel('Cluster')
plt.ylabel('Feature')
plt.subplots_adjust(left=0.3, right=0.8)
plt.show()


total_time = (end_time - start_time) * 1000
print(f"Tempo impiegato: {total_time} " )
# Out:
# Numero di outlier: 0
# Punteggio Silhouette: 0.7885683529501489
# Punteggio Calinski: 6168.600356427222
# Punteggio Davies: 0.34231957173003796
# Tempo impiegato: 184.69834327697754

# %% [markdown]
# ### <center> __Spiegazione del codice__ </center>
# Per facilitare la visualizzazione dei risultati dell'implementazione degli algoritmi di clustering, ho scritto un unico codice in cui in base al dataset (dataset_path) e l'algoritmo (algorithm) selezionati è possibile ottenere lo specifico risultato.
#
# Per prima cosa ho eseguito la lettura del dataset selezionato mediante *pd.read_csv* e ho salvato tale lettura nella variabile *dataset* così da stampare a video le informazioni delle colonne, comprendendo il tipo di ogni valore presente per ogni colonna, cioè tutti numerici, e il numero di valori presente per ogni colonna. Una volta letto il dataset, ho impostato la normalizzazione dei dati (scaler) mediante MinMaxScaler così da permettere di assegnare un peso ad ogni valore in modo tale da non favorire di più alcuni valori e dunque avere una influenza sul clustering uguale per ogni valore. In base al dataset selezionato ho impostato tutti gli iperparametri in base alla configurazione migliore di ogni algoritmo di clustering, ottenuta mediante una precedente analisi che comprende diverse prove con diverse configurazioni degli iperparametri. Inoltre, su alcuni dataset ho impostato lo scaler in StandardScaler poichè ho ottenuto un risultato più efficiente rispetto che alla normalizzazione mediante MinMaxScaler. Successivamente ho eseguito la normalizzazione del dataset, assegnando il risultato dell'operazione alla variabile *features_scaled*, così da procedere con la riduzione della dimensionalità dei dati del dataset mediante PCA che ha permesso una migliore visualizzazione e un miglior clustering, settando *n_components=2* notando che fosse il numero migliore di features da mantente per la formazione dei cluster. Nello specifico, PCA assegna delle nuove coordinate ad ogni punto e tramite plot si mostra il discostamento del valore assegnato al punto dato rispetto alla media dei valori. Andando avanti si ha l'implementazione di ogni algoritmo di clustering in questione, di seguito indico le specifiche dell'implementazione:
# * K-means: Ho inizialmente impostato un range di cluster da formare così da utilizzare la tecnica del gomito per visualizzare la curvatura dell'inerzia così da comprendere il numero di cluster più efficiente da formare. Dopo aver calcolato l'inerzia per ogni k settato, ho mostrato la curvatura tramite un grafico intitolato __Tecnica del Gomito__. Successivamente ho eseguito l'algoritmo e l'ho addestrato con le features ottenute dopo la riduzione della dimensionalità dei dati, per poi mostrare il clustering ottenuto;
# * Spectral: Come per l'implementazione di k-means, anche per il clustering spettrale ho utilizzato la tecnica del gomito per comprendere il numero di cluster da formare per poi procedere con l'esecuzione dell'algoritmo come per k-means;
# * Agglomerative: Prima di procedere con l'esecuzione dell'algoritmo, ho ottenuto il dendrogramma dei cluster mediante una specifica del metodo di collegamento impostato in base al dataset selezionato. Successivamente, come per gli altri algoritmi, ho eseguito il clustering e ho mostrato a video il risultato;
# * Birch, DBSCAN, Mean-Shift: Per questi algoritmi non ho utilizzato delle tecniche per comprendere il numero di cluster da formare ma ho semplicemente testato l'esecuzione tramite diverse configurazioni, dunque si ha direttamente l'esecuzione degli algoritmi e la generazione di un grafico per mostrare il clustering ottenuto;
#
# Nella parte successiva, ho calcolato e stampato il valore delle metriche di valutazione della bontà del clustering ottenuto. Infine, ho generato l'heatMap per comprendere la differenza tra i cluster prodotti dopo l'esecuzione degli algoritmi.
#
# ## <center> __Risultati ottenuti__</center>
# Di seguito mostro per ogni dataset tutti i risultati ottenuti e l'apposita interpretazione:
#
# ### <center>__10_7717_peerj_5665_dataYM2018_neuroblastoma__</center>
# Questo dataset è risultato l'unico che richiedeva una trasformazione dei dati di tipo object in tipo numerico, ciò l'ho ottenuto mediante LabelEncoder, in cui eseguivo la trasformazione per ogni colonna di tipo object del dataset.Inoltre, ho eliminato le colonne __outcome__ e __time_months__ poichè ritengo non sia funzionali per il clustering, infatti togliendole ho ottenuto un risultato delle metrcihe di valutazione più vantaggioso.
# Di seguito riporto il risultato ottenuto per ogni algoritmo utilizzato:
# * K-Means:
#     o	Punteggio Silhouette: 0.5080295721401309
#     o	Punteggio Calinski: 240.53309586611275
#     o	Punteggio Davies: 0.6568102928570567
# * Agglomerative:
#     o	Punteggio Silhouette: 0.5140964641717315
#     o	Punteggio Calinski: 216.94681905154346
#     o	Punteggio Davies: 0.6701715057626363
# * BIRCH:
#     o	Punteggio Silhouette: 0.553941186035796
#     o	Punteggio Calinski: 122.3186774157321
#     o	Punteggio Davies: 0.5499380553013672
# * DBSCAN:
#     o	Punteggio Silhouette: 0.4701235250250561
#     o	Punteggio Calinski: 55.92592880991509
#     o	Punteggio Davies: 0.5314677757955671
# * Spectral:
#     o	Punteggio Silhouette: 0.5152556302079532
#     o	Punteggio Calinski: 204.13989817056975
#     o	Punteggio Davies: 0.5962381848452224
# * Mean-shift:
#     o	Punteggio Silhouette: 0.5699163842004293
#     o	Punteggio Calinski: 203.8494758362625
#     o	Punteggio Davies: 0.6880645237060501
#
# Di seguito mostro le feature principali che differenziano i cluster formati dai diversi algoritmi:
#
# * Età (Age): L'età risulta una caratteristica distintiva in tutti gli algoritmi. Nei cluster con età più elevata, generalmente si osserva anche un alto rischio e un maggiore utilizzo di radioterapia.
# * Sesso (Sex): Nei cluster in cui il sesso è prevalentemente maschile, si osservano generalmente valori elevati di rischio e interventi terapeutici intensivi come la radioterapia.
# * Grado di differenziazione cellulare (Degree of Differentiation): Questa caratteristica varia significativamente tra i cluster, particolarmente nel Birch e nel Mean-Shift, suggerendo che potrebbe essere un fattore chiave nella separazione dei cluster.
# * Rischio (Risk) e Radioterapia (Radiation): Questi due fattori sono altamente correlati, con cluster ad alto rischio che mostrano un maggiore utilizzo di radioterapia.
#
# Concludo con una panoramica comparativa tra il clustering prodotto dai diveri algoritmi:
# * K-means e Agglomerative Clustering: Questi algoritmi tendono a creare cluster basati principalmente su età, rischio e radioterapia, ma mostrano una buona distribuzione tra i diversi fattori.
# * Birch e DBSCAN: Mostrano differenze più evidenti nel grado di differenziazione cellulare, e sono utili per identificare gruppi con specifiche combinazioni di caratteristiche.
# * Mean-Shift: Risulta efficace nel separare cluster basati su differenze significative di età e rischio. Inoltre, ha ottenuto i migliori punteggi per la distinzione e la definizione dei cluster, rendendolo il più efficace in termini di qualità del clustering tra quelli elencati.
# * Spectral Clustering: Offre una suddivisione equilibrata basata su età e rischio, ma è particolarmente utile per identificare cluster senza interventi significativi.
# * Agglomerative Clustering: è risultato l'algoritmo più efficiente per il punteggio Calinski-Harabasz, indicando buoni risultati nella compattezza e separazione dei cluster.
#
# ### <center>__journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED__</center>
# Per l'implementazione degli algoritmi su questo dataset non ho eliminato nesuna colonna e non ho dovuto trasformare nessun valore poichè risultano tutti di tipo numerico e dunque adatti a tutti gli algoritmi.
# Di seguito riporto il risultato ottenuto per ogni algoritmo utilizzato:
# * K-Means:
#     o	Punteggio Silhouette: 0.7886692775646892
#     o	Punteggio Calinski: 6168.816682845355
#     o	Punteggio Davies: 0.34285406295944465
# * Agglomerative:
#     o	Punteggio Silhouette: 0.7873156306400714
#     o	Punteggio Calinski: 6081.3224061200135
#     o	Punteggio Davies: 0.34601659530053014
#
# * BIRCH:
#     o	Punteggio Silhouette: 0.7886692782308596
#     o	Punteggio Calinski: 6168.816751415986
#     o	Punteggio Davies: 0.3428540556328731
#
# * DBSCAN:
#     o	Punteggio Silhouette: 0.5279663190967729
#     o	Punteggio Calinski: 1023.2057473087468
#     o	Punteggio Davies: 0.9884871982509923
#
# * Spectral:
#     o	Punteggio Silhouette: 0.7886692773025853
#     o   Punteggio Calinski: 6168.816698795138
# 	o   Punteggio Davies: 0.34285405904868077
#
# * Mean-shift:
#     o	Punteggio Silhouette: 0.7885683532432746
#     o	Punteggio Calinski: 6168.600380737398
#     o	Punteggio Davies: 0.34231956959787657
#
#
# Di seguito mostro le feature principali che differenziano i cluster formati dai diversi algoritmi:
#
# * APACHE II: Questa variabile è risultata particolarmente influente in tutti i clustering. Essa riflette la gravità della condizione dei pazienti e ha giocato un ruolo chiave nel separare i pazienti in base alla loro gravità clinica.
# * SOFA: Simile a APACHE II, il punteggio SOFA è cruciale per valutare il rischio di mortalità nei pazienti con disfunzioni o fallimenti d'organo. È emersa come una caratteristica centrale per distinguere i cluster di pazienti con differenti prognosi.
# * Mortalità (Mortality): Questa caratteristica varia significativamente tra i cluster, particolarmente nel Birch e nel Mean-Shift, suggerendo che potrebbe essere un fattore chiave nella separazione dei cluster.
#
# Concludo con una panoramica comparativa tra il clustering prodotto dai diveri algoritmi:
# * K-means: Tende a segmentare i pazienti in base a caratteristiche cruciali come APACHE, SOFA e la mortalità. Inoltre, tende a creare cluster con bordi più netti e separati, evidenziando chiare differenze tra pazienti più giovani e meno gravi rispetto a quelli più anziani e con condizioni più critiche. Risulta il più vantaggioso assieme a Mean-shift, Spectral-Clustering e Birch.
# * Agglomerative: Produce una frammentazione più fine, specialmente quando si tratta di cluster con lievi variazioni nei punteggi SOFA e CRP. Questo è vantaggioso in questi contesti dove è necessaria una maggiore precisione nella stratificazione del rischio.
# * Birch: Tende a rivelare sottostrutture nei dati, creando cluster che possono catturare variazioni sottili nei dati, come differenze nei punteggi CRP e mortalità tra pazienti di età simile. Tramite i punteggi ottenuti risulta il più vantaggioso assieme a k-Means, Spectral-Clustering e Mean-shift.
# * DBSCAN: è più efficace nel rilevare gruppi distinti e separati, specialmente quando ci sono outlier o noise nei dati. Tuttavia, DBSCAN ha generato un numero ridotto di cluster, il che lo rende più adatto per identificare cluster ben separati ma meno per rilevare variazioni sottili come Birch.
# * Mean-Shift: Offre i punteggi più noteovoli come per Spectral-Clustering, k-Means e Birch, mostrando una capacità di adattamento dinamico alle densità locali dei dati. Questo si traduce in cluster che sono più omogenei e che bilanciano bene le variabili come età, SOFA, e mortalità. Rispetto a K-means, Mean-Shift è meno rigido nella definizione dei cluster, permettendo una maggiore flessibilità nel catturare la variazione naturale nei dati clinici.
# * Spectral Clustering: dimostra una chiara superiorità nella creazione di cluster equilibrati che riflettono una segmentazione bilanciata tra variabili chiave come APACHE II, SOFA, CRP e mortalità. Tramite i punteggi ottenuti risulta il più vantaggioso assieme a k-Means, Birch e Mean-shift.
#
# ### <center>__journal.pone.0158570_S2File_depression_heart_failure__</center>
# Per l'implementazione degli algoritmi su questo dataset ho dovuto solamente eliminare la colonna *id* che risultava fuori contesto del clustering. Inoltre, ho utilizzato per la normalizzazione StandardScaler che ha permesso dei risultati più efficienti rispetto MinMaxScaler.
# Di seguito riporto il risultato ottenuto per ogni algoritmo utilizzato:
# * k-Means :
#     o	Punteggio Silhouette: 0.4614865205968457
#     o	Punteggio Calinski: 464.9895012732667
#     o	Punteggio Davies: 0.7577986989342488
# * Agglomerative :
#     o	Punteggio Silhouette: 0.42145736250652177
#     o	Punteggio Calinski: 372.9614919427643
#     o	Punteggio Davies: 0.7884122564995812
# * BIRCH :
#     o	Punteggio Silhouette: 0.45951474659138364
#     o	Punteggio Calinski: 456.39405748576115
#     o	Punteggio Davies: 0.7691917892156793
# * DBSCAN:
#     o	Punteggio Silhouette: 0.3743507697189627
#     o	Punteggio Calinski: 4.107666169701562
#     o	Punteggio Davies: 0.4365557406324753
# * Spectral:
#     o	Punteggio Silhouette: 0.46253546017213537
#     o	Punteggio Calinski: 460.1067044433756
#     o	Punteggio Davies: 0.7562080130840766
# * Mean-shift:
#     o	Punteggio Silhouette: 0.46159866184554
#     o	Punteggio Calinski: 463.5994892713585
#     o	Punteggio Davies: 0.7565948411400716
#
#
# Di seguito mostro le feature principali che differenziano i cluster formati dai diversi algoritmi:
#
# * Time from HF to Death: Questa caratteristica è decisamente dominante in tutti i cluster, mostrando chiari gradienti tra i gruppi. Ad esempio, i pazienti con tempi di sopravvivenza significativamente più brevi (intorno ai 400 giorni) si distinguono in un cluster specifico.
# * PHQ-9: Riflette la gravità della depressione, varia tra i cluster e può essere correlato alla prognosi dei pazienti. I punteggi più alti si associano spesso con cluster in cui la sopravvivenza è minore.
# * Elevated level of BNP/NT-BNP: I livelli elevati di BNP/NT-BNP sono più frequenti nei cluster con maggior rischio e peggiori outcome, evidenziando la sua importanza prognostica.
# * Serum Sodium: Nonostante non vari drasticamente tra i cluster, il livello di sodio nel siero rimane una costante in tutti i gruppi, suggerendo un suo potenziale impatto clinico.
#
# Concludo con una panoramica comparativa tra il clustering prodotto dai diveri algoritmi:
# * Agglomerative Clustering: Questo algoritmo tende a creare cluster ben distinti sulla base della sopravvivenza (Time from HF to Death) e PHQ-9. È evidente una separazione netta nei cluster, con uno specifico gruppo che presenta una sopravvivenza drammaticamente ridotta e alto rischio.
# * Birch: I cluster di Birch mostrano differenze significative in termini di sopravvivenza e livelli di sodio. Birch tende a raggruppare i pazienti in base a una combinazione di caratteristiche prognostiche e di comorbilità, con un'enfasi sulla mortalità e ospedalizzazione.
# * K-means: Ha prodotto cluster che sono particolarmente influenzati da variabili come il tempo di sopravvivenza e i livelli di BNP/NT-BNP. I cluster sono distinti e riflettono vari livelli di rischio, con chiara separazione per pazienti ad alto rischio di morte.
# * Spectral Clustering: Offre una separazione delicata dei cluster, con una particolare attenzione alle differenze nei tempi di sopravvivenza e punteggi PHQ-9.
# * Mean-Shift crea cluster che enfatizzano le differenze nella sopravvivenza e nei punteggi PHQ-9, simile a K-means, ma con una segmentazione più sfumata. Questo metodo identifica gruppi distinti con differenze significative nelle caratteristiche cliniche, specialmente nei livelli di BNP/NT-BNP e nella sopravvivenza. Grazie alle sue performance risulta il più vantaggioso da utilizzare su questo dataset rispetto agli altri algoritmi;
# * DBSCAN è particolarmente efficace nel separare gruppi con tratti distintivi come una bassa sopravvivenza e alti punteggi PHQ-9, anche in presenza di noise (outlier). Questo algoritmo evidenzia pazienti con outlier in termini di variabili critiche come la sopravvivenza e l'ospedalizzazione, mostrando la sua capacità di gestire dati con rumore.
#
#
# ### <center>__journal.pone.0175818_S1Dataset_Spain_cardiac_arrest_EDITED__</center>
# Per l'implementazione degli algoritmi su questo dataset non ho dovuto eseguire nessuna pre-elaborazione dei dati, come per alcuni degli altri dataset, dunque ho utilizzato il dataset direttamente fornito.
# Di seguito riporto il risultato ottenuto per ogni algoritmo utilizzato:
# * k-Means:
#     o	Punteggio Silhouette: 0.4872783768105561
#     o	Punteggio Calinski: 439.07445652003247
#     o	Punteggio Davies: 0.7630718463491025
# * Agglomerative:
#     o	Punteggio Silhouette: 0.48346355588839895
#     o   Punteggio Calinski: 428.18688664872815
#     o   Punteggio Davies: 0.7338432943914197
# * BIRCH:
#     o	Punteggio Silhouette: 0.45892839559872034
#     o	Punteggio Calinski: 428.3040710667752
#     o	Punteggio Davies: 0.7771688784824728
# * DBSCAN:
#     o	Punteggio Silhouette: 0.4001996176901281
#     o	Punteggio Calinski: 216.2142804151739
#     o	Punteggio Davies: 1.1833675551962182
# * Spectral (k=4):
#     o	Punteggio Silhouette: 0.48127534717580683
#     o	Punteggio Calinski: 423.8159253379636
#     o	Punteggio Davies: 0.7551972279839279
# * Mean-shift (ha formato 5 cluster):
#     o	Punteggio Silhouette: 0.4635466300130338
#     o	Punteggio Calinski: 369.6970433998604
#     o	Punteggio Davies: 0.660749530138165
#
# Di seguito mostro le feature principali che differenziano i cluster formati dai diversi algoritmi:
#
# * Age_years: L'età è una delle caratteristiche che mostra una variazione significativa tra i cluster. L'età avanzata è spesso associata a una maggiore vulnerabilità e, di conseguenza, a un esito peggiore. Nei vari heatmap, i cluster con valori di età più elevati tendono anche ad avere una maggiore mortalità, suggerendo che l'età è un determinante cruciale degli esiti.
# * Exitus: Questa è la caratteristica più critica in tutti i heatmap. I valori di Exitus indicano la mortalità, con valori più alti che rappresentano una maggiore probabilità di esito fatale. La variazione di Exitus tra i cluster è significativa perché rivela come diversi gruppi di pazienti abbiano diverse probabilità di sopravvivenza.
# * Endotracheal_intubation: Questo parametro rappresenta l'intubazione endotracheale, una procedura comune nei pazienti in condizioni critiche. La variazione tra i cluster può indicare diverse strategie di gestione o necessità cliniche. Ad esempio, i cluster con un maggiore utilizzo dell'intubazione potrebbero rappresentare pazienti più gravi o in condizioni più critiche.
#
# Concludo con una panoramica comparativa tra il clustering prodotto dai diveri algoritmi:
# * Agglomerative Clustering: Eccelle nella creazione di cluster distinti, segmentando pazienti con diverse gravità basate su età e mortalità.
# * Birch: Exitus e Age_years sono fortemente correlati nei cluster creati da Birch. I pazienti più anziani (Cluster 4) mostrano una mortalità significativamente più alta. Time_min è un altro fattore critico, con tempi di intervento più lunghi associati a esiti peggiori. Birch separa bene i pazienti in base a queste caratteristiche, evidenziando gruppi con diverse probabilità di sopravvivenza e differenti strategie di gestione clinica.
# * K-means: Tende a creare cluster distinti basati su Exitus e Age_years, simile a Birch, ma con una segmentazione più uniforme. I cluster con pazienti più anziani (Cluster 0 e Cluster 3) mostrano una mortalità più alta. Anche Endotracheal_intubation e Asystole sono parametri distintivi nei cluster creati da K-means, che separano i pazienti in base alla gravità della loro condizione al momento dell'intervento. Inoltre, risulta come l'algoritmo più efficiente per il clustering sul dataset in questione;
# * Mean-Shift: Fornisce cluster più bilanciati e meno frammentati, simili a K-means ma con una distribuzione interna più omogenea.
# * DBSCAN: Mostra una separazione meno marcata rispetto a Birch, ma identifica comunque differenze significative in Exitus e Age_years. I cluster creati da DBSCAN evidenziano una leggera variazione nella mortalità, con alcuni cluster (Cluster 1) che mostrano una mortalità inferiore rispetto ad altri. Anche qui, Endotracheal_intubation e Bystander sono importanti per distinguere i gruppi con diversi esiti.
# * Spectral Clustering: Genera cluster che mostrano una chiara differenziazione in termini di Exitus, Age_years e Endotracheal_intubation. Il metodo evidenzia cluster con mortalità alta (Cluster 0) associati a pazienti più anziani e con condizioni critiche (ad esempio, alta asistolia). Time_min e Cardiac_arrest_at_home sono altri parametri che variano tra i cluster, suggerendo che la tempestività e il luogo dell'arresto cardiaco sono fattori determinanti negli esiti.
#
#
# ### <center>__Takashi2019_diabetes_type1_dataset_preprocessed__</center>
# Per l'implementazione degli algoritmi su questo dataset ho dovuto solamente eliminare la colonna *id* che risultava fuori contesto del clustering. Inoltre, ho utilizzato per la normalizzazione StandardScaler che ha permesso dei risultati più efficienti rispetto MinMaxScaler.
# Di seguito riporto il risultato ottenuto per ogni algoritmo utilizzato:
# * k-Means:
#     o	Punteggio Silhouette: 0.7457452893071463
#     o	Punteggio Calinski: 294.11733059625647
#     o	Punteggio Davies: 0.33798090644365025
# * Agglomerative:
#     o	Punteggio Silhouette: 0.7457452893071463
#     o   Punteggio Calinski: 294.11733059625647
#     o   Punteggio Davies: 0.33798090644365025
# * BIRCH:
#     o	Punteggio Silhouette: 0.7457452893071463
#     o	Punteggio Calinski: 294.11733059625647
#     o	Punteggio Davies: 0.33798090644365025
# * DBSCAN:
#     o	Punteggio Silhouette: 0.7248397445620702
#     o	Punteggio Calinski: 204.97988068381505
#     o	Punteggio Davies: 0.9651566129182922
# * Spectral:
#     o	Punteggio Silhouette: 0.7457452893071463
#     o	Punteggio Calinski: 294.11733059625647
#     o	Punteggio Davies: 0.33798090644365025
# * Mean-shift:
#     o	Punteggio Silhouette: 0.3524870815823994
#     o	Punteggio Calinski: 35.02720480041022
#     o	Punteggio Davies: 1.1687574336466928
#
# Di seguito mostro le feature principali che differenziano i cluster formati dai diversi algoritmi:
#
# * OC: Questo parametro è abbastanza stabile tra i cluster, ma presenta delle variazioni lievi che possono indicare differenti gruppi con valori di OC che oscillano tra 15 e 18.
# * eGFR: Sembra essere una caratteristica discriminante tra i cluster, con differenze abbastanza marcate. Questo suggerisce che la funzione renale può essere un fattore importante nella distinzione dei cluster.
# * Grip Strength e Knee Extension Strength: Questi parametri fisici variano tra i cluster, con differenze notevoli che potrebbero riflettere differenti livelli di funzionalità fisica.
#
# Concludo con una panoramica comparativa tra il clustering prodotto dai diveri algoritmi:
# * Agglomerative Clustering: Crea cluster distinti principalmente basati su eGFR, grip strength, e OC. Questo suggerisce che l'algoritmo tende a creare raggruppamenti in base a parametri fisiologici e funzionali. Complessivamente risulta il più vantaggioso assieme a Birch.
# * Birch: Riesce a mantenere una buona separazione basata su eGFR, OC, e peso corporeo, ma tende a creare cluster leggermente più omogenei rispetto a DBSCAN. Risulta il più vantaggioso assieme all'algoritmo Agglomerative Clustering.
# * K-means: Genera cluster simili a quelli dell'Agglomerative, ma con una distribuzione leggermente diversa. La forza muscolare e l'eGFR sono le caratteristiche principali che guidano la separazione dei cluster. Inoltre, i punteggi ottenuti dalle metriche di valutazione dimostrano un'ottima bontà dei cluster prodotti come per Agglomerative, Birch e Spectral clustering, ma richiede più tempo di esecuzione.
# * Mean-Shift: Evidenzia differenze più marcate nei parametri come eGFR e grip strength. Questo algoritmo tende a creare cluster meno definiti rispetto a K-Means e Agglomerative, ma mette in risalto gruppi con caratteristiche fisiche e renali distintive.
# * DBSCAN: Utilizza eGFR come uno dei parametri chiave per differenziare i cluster. Questo algoritmo è efficace nel trovare outlier e crea cluster basati su densità, rendendo la distinzione più basata su caratteristiche fisiologiche estreme, come una bassa o alta forza muscolare.
# * Spectral Clustering: Mantiene una separazione più netta tra i cluster, con una maggiore enfasi su parametri come il peso, la forza muscolare e il OC. Questo metodo sembra accentuare le differenze nei parametri fisici.  Inoltre, i punteggi ottenuti dalle metriche di valutazione dimostrano un'ottima bontà dei cluster prodotti come per Agglomerative, Birch e k-Means, ma richiede più tempo di esecuzione.

# %% [markdown]
# | **Colonna** | **Descrizione** | **Valori** |
# |-------------|-----------------|------------|
# | **age (età)** | I valori rappresentano le fasce d'età in cui i pazienti con neuroblastoma vengono classificati, secondo la classificazione INRG (International Neuroblastoma Risk Group). | - 0: Neonati (inferiori a 18 mesi) <br> - 1: Bambini (18 mesi - 12 anni) <br> - 2: Adolescenti (oltre 12 anni) |
# | **sex (sesso)** | Indica il sesso dei pazienti. | - 0: Maschio <br> - 1: Femmina |
# | **site (sito)** | Si riferisce alla localizzazione primaria del tumore. I codici probabilmente indicano aree anatomiche comuni per il neuroblastoma, come addome, torace, o altri siti tipici. | *Valori numerici* |
# | **stage (stadio)** | Lo stadio della malattia, probabilmente basato sul sistema INRG. | *Valori numerici* |
# | **risk (rischio)** | Il livello di rischio del paziente secondo i fattori prognostici identificati dallo studio. | - 0: Basso rischio <br> - 1: Alto rischio |
# | **time_months (tempo in mesi)** | Rappresenta la durata, in mesi, che i pazienti sono stati seguiti dopo il trattamento o la diagnosi. | *Valori numerici* |
# | **autologous_stem_cell_transplantation (trapianto di cellule staminali autologhe)** | Indica se il paziente ha ricevuto un trapianto di cellule staminali autologhe. | - 0: Non ricevuto <br> - 1: Ricevuto |
# | **radiation (radioterapia)** | Indica se il paziente ha ricevuto radioterapia come parte del trattamento. | - 0: Non ricevuta <br> - 1: Ricevuta |
# | **degree_of_differentiation (grado di differenziazione)** | Indica il grado di differenziazione delle cellule tumorali, un fattore prognostico importante. | - 0: Basso grado <br> - 1: Moderato <br> - 2: Alto grado |
# | **UH_or_FH** | Indica una classificazione ereditabile o familiare della malattia. | - 0: Non familiare <br> - 1: Condizione familiare o ereditaria |
# | **MYCN_status** | Lo stato del gene MYCN, un marker genetico cruciale per determinare l'aggressività del neuroblastoma. | - 0: Non amplificato (prognosi generalmente migliore) <br> - 1: Amplificato (prognosi generalmente peggiore) |
# | **surgical_methods (metodi chirurgici)** | Indica se è stato eseguito un intervento chirurgico per rimuovere il tumore. | - 0: Non chirurgico o meno invasivo <br> - 1: Chirurgico (probabilmente chirurgia maggiore o resezione tumorale) |
# | **outcome (esito)** | Rappresenta l'esito del paziente. | - 0: Negativo (morte o progressione della malattia) <br> - 1: Positivo (sopravvivenza o remissione) |

# %% [markdown]
# | Colonna                                                 | Descrizione                                                                                                                                                                                                                      | Valori                                                                                       |
# |---------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------|
# | `age (età)`                                              | Rappresenta le fasce d'età in cui i pazienti con neuroblastoma vengono classificati.                                                                                                                                              | 0: Neonati (inferiori a 18 mesi) <br> 1: Bambini (18 mesi - 12 anni) <br> 2: Adolescenti (oltre 12 anni) |
# | `sex (sesso)`                                            | Indica il sesso dei pazienti.                                                                                                                                                                                                    | 0: Maschio <br> 1: Femmina                                                                   |
# | `site (sito)`                                            | Si riferisce alla localizzazione primaria del tumore. I codici indicano le aree anatomiche comuni per il neuroblastoma, come addome, torace, o altri siti tipici.                                                                  | (valori numerici che rappresentano aree anatomiche specifiche)                                |
# | `stage (stadio)`                                         | Lo stadio della malattia si basa sul sistema INRG, che classifica i pazienti in base alla progressione del tumore.                                                                                                                 | (valori numerici che rappresentano gli stadi del tumore)                                      |
# | `risk (rischio)`                                         | Il livello di rischio del paziente secondo i fattori prognostici identificati dallo studio.                                                                                                                                         | 0: Basso rischio <br> 1: Alto rischio                                                        |
# | `time_months (tempo in mesi)`                            | Rappresenta la durata, in mesi, che i pazienti sono stati seguiti dopo il trattamento o la diagnosi.                                                                                                                               | Valore numerico (mesi)                                                                       |
# | `autologous_stem_cell_transplantation (trapianto di cellule staminali autologhe)` | Indica se il paziente ha ricevuto un trapianto di cellule staminali autologhe.                                                                                                                                                      | 0: Non ricevuto <br> 1: Ricevuto                                                             |
# | `radiation (radioterapia)`                               | Indica se il paziente ha ricevuto radioterapia come parte del trattamento.                                                                                                                                                         | 0: Non ricevuta <br> 1: Ricevuta                                                             |
# | `degree_of_differentiation (grado di differenziazione)`  | Indica il grado di differenziazione delle cellule tumorali, che è un importante fattore prognostico.                                                                                                                               | 0: Basso grado <br> 1: Moderato <br> 2: Alto grado                                           |
# | `UH_or_FH`                                               | Indica una classificazione ereditabile o familiare della malattia.                                                                                                                                                                 | 0: Non familiare <br> 1: Condizione familiare o ereditaria                                   |
# | `MYCN_status`                                            | Lo stato del gene MYCN, un marker genetico cruciale per determinare l'aggressività del neuroblastoma.                                                                                                                               | 0: Non amplificato (prognosi generalmente migliore) <br> 1: Amplificato (prognosi peggiore)  |
# | `surgical_methods (metodi chirurgici)`                   | Indica se è stato eseguito un intervento chirurgico per rimuovere il tumore.                                                                                                                                                       | 0: Non chirurgico o meno invasivo <br> 1: Chirurgico (probabilmente chirurgia maggiore)       |
# | `outcome (esito)`                                        | Rappresenta l'esito del paziente.                                                                                                                                                                                                 | 0: Negativo (morte o progressione della malattia) <br> 1: Positivo (sopravvivenza o remissione) |

# %% [markdown]
# ## <center>__Tabella per il dataset:  *10_7717_peerj_5665_dataYM2018_neuroblastoma*__</center>
# | Algoritmo | Punteggio Silhouette | Punteggio Calinski | Punteggio Davies | Numero di Cluster | Velocità di esecuzione (ms) | Numero di Outlier|
# |-----------|-----------|-----------|-----------|-----------|-----------|-----------|
# | K-Means  | 0.508  | 240  | 0.656  | 3  | 350 | 9 |
# | DBSCAN  | 0.470  | 55.925  | 0.531  | 2  | 1  |0 |
# | BIRCH  | 0.553  | 122  | 0.549  | 3  | 2  |8|
# | Agglomerative  | 0.514  | 216.946  | 0.670  | 4  | 1  |9|
# | SpectralClustering  | 0.515  | 204  | 0.596  | 3  | 1100  |9|
# | MeanShift  | 0.569  | 203.849  | 0.688  | 2  | 200  |0|

# %% [markdown]
# ## <center>__Tabella per il dataset:  *journal.pone.0158570_S2File_depression_heart_failure*__</center>
# | Algoritmo | Punteggio Silhouette | Punteggio Calinski | Punteggio Davies | Numero di Cluster | Velocità di esecuzione (ms) | Numero di Outlier|
# |-----------|-----------|-----------|-----------|-----------|-----------|-----------|
# | K-Means  | 0.461  | 464.989  | 0.757  | 3  | 280 |22|
# | DBSCAN  | 0.374  | 4  | 0.436  | 2  | 2  | 1|
# | BIRCH  | 0.459  | 456  | 0.769  | 3  | 4  |22|
# | Agglomerative  | 0.421  | 372.961  | 0.788  | 3 | 4  |22|
# | SpectralClustering  | 0.462  | 460  | 0.756  | 3  | 380| 22 |
# | MeanShift  | 0.461  | 463.599  | 0.756  | 3  | 47  |4|

# %% [markdown]
# ## <center> __Tabella per il dataset: *journal.pone.0175818_S1Dataset_Spain_cardiac_arrest_EDITED.*__</center>
# | Algoritmo | Punteggio Silhouette | Punteggio Calinski | Punteggio Davies | Numero di Cluster | Velocità di esecuzione (ms) | Numero Outlier|
# |-----------|-----------|-----------|-----------|-----------|-----------|-----------|
# | K-Means  | 0.487  | 439  | 0.763  | 4 | 220 |21|
# | DBSCAN  | 0.4  | 216  | 1.183  | 3 | 2  |0 |
# | BIRCH  | 0.458  | 428  | 0.777  | 5  | 3  |21|
# | Agglomerative  | 0.483  | 428  | 0.733  | 4 | 4  |21|
# | SpectralClustering  | 0.481  | 423.815  | 0.755  | 4 | 550  |21|
# | MeanShift  | 0.463  | 369.697  | 0.66  | 5  | 400 |0|

# %% [markdown]
# ## <center> __Tabella per il dataset: *journal.pone.0148699_S1_Text_Sepsis_SIRS_EDITED*__</center>
# | Algoritmo | Punteggio Silhouette | Punteggio Calinski | Punteggio Davies | Numero di Cluster | Velocità di esecuzione (ms) | Numero di Outlier |
# |-----------|-----------|-----------|-----------|-----------|-----------| -------|
# | K-Means  | 0.788  | 6168.816  | 0.342  | 4 | 270 | 63 |
# | DBSCAN  | 0.527  | 1023  | 0.988  | 2 | 8  | 0 |
# | BIRCH  | 0.788 | 6168.816  | 0.342  | 4  | 10 | 63 |
# | Agglomerative  | 0.787  | 6081  | 0.346  | 4 | 35 | 63 |
# | SpectralClustering  | 0.788  | 6168  | 0.342  | 4  |  1900 | 63|
# | MeanShift  | 0.788  | 6168  | 0.342  | 4  | 60  | 0|

# %% [markdown]
# ## <center> __Tabella per il dataset: *Takashi2019_diabetes_type1_dataset_preprocessed*__ </center>
# | Algoritmo | Punteggio Silhouette | Punteggio Calinski | Punteggio Davies | Numero di Cluster | Velocità di esecuzione (ms) | Numero di Outlier|
# |-----------|-----------|-----------|-----------|-----------|-----------|-----------|
# | K-Means  | 0.745  | 294  | 0.337  | 3 | 170 |4|
# | DBSCAN  | 0.724  | 204  | 0.965  | 4 | 1  |3 |
# | BIRCH  | 0.745 | 294  | 0.337  | 3  | 1  |4|
# | Agglomerative  | 0.745  | 294  | 0.337  | 3 | 1  |4|
# | SpectralClustering  | 0.745  | 294  | 0.337  | 3 |  200 |4|
# | MeanShift  | 0.352  | 35  | 1.168  | 2  |  30 |0|

# %% [markdown]
# ## <center>**Tabella riassuntiva degli articoli scientifici**</center>
#
#
# | **Articolo** | **Fonte** | **Punteggio SJR** | **Obiettivo Principale** | **Algoritmi di Clustering Utilizzati** | **Dataset** | **Metriche di Valutazione** | **Risultati Principali** | **Libreria scikit-learn/Python/R** |
# |--------------|-----------|------------------|--------------------------|--------------------------------------|-------------|----------------------------|--------------------------|-----------------------------------|
# | Identifying subgroups in heart failure patients with multimorbidity by clustering and network analysis | BMC Medical Informatics and Decision Making | Q1 | Identificare e caratterizzare sottogruppi di pazienti con insufficienza cardiaca e multimorbilità | Clustering gerarchico agglomerativo (metodo di Ward) | 54,827 pazienti | Punteggio Silhouette, Calinski-Harabasz, Davies-Bouldin | Miglior risultato con metodo di Ward, 4 cluster distinti identificati | Non specificato |
# | Comparing machine learning clustering with latent class analysis on cancer symptoms' data | 2016 IEEE Healthcare Innovation POCT | ? | Confrontare 5 algoritmi di clustering con LCA per identificare sottogruppi di pazienti con sintomi di cancro | K-means, Birch, Spectral, Gerarchico agglomerativo, K-modes | 582 e 1329 cartelle cliniche (2 dataset) | Coefficiente Silhouette, Coefficiente Jaccard | K-modes risulta il più efficiente; identificazione di 4 gruppi simili a LCA | Sì (scikit-learn) |
# | Using Medical Data and Clustering Techniques for a Smart Healthcare System | MDPI Electronics | Q2 | Migliorare il sistema SHCM per la gestione della conoscenza sanitaria tramite clustering | K-means, Gerarchico agglomerativo, K-means autoencoder, K-means SOM | Dati clinici su malattie cardiache, diabete, cancro, ictus, COVID-19 | Calinski-Harabasz, Davies-Bouldin, Silhouette | K-means risulta migliore; identificazione di pattern rilevanti | Non specificato |
# | Simulation-derived best practices for clustering clinical data | Journal of Biomedical Informatics | Q3 | Riassumere studi precedenti su clustering di dati dell’Alzheimer per migliorare diagnosi e progressione della malattia | K-means, K-means-mode, Clustering multistrato, Gerarchico agglomerativo | Dati su Alzheimer | Valutazioni basate su conoscenze pregresse, validità del clustering | K-means e Gerarchico identificano cluster con pattern rilevanti legati a AD | Sì (scikit-learn) |
# | Data-Driven Analytics for Personalized Medical Decision Making | MDPI Mathematics | Q2 | Sviluppare un nuovo approccio per decisioni mediche personalizzate tramite clustering | K-means, DBSCAN, BIRCH | Dati clinici (es. diabete) | Hopkins Statistics, Dunn Index | L’algoritmo proposto supera BIRCH; supporto alle decisioni mediche personalizzate | Sì (scikit-learn) |
# | Spectral clustering of risk score trajectories stratifies sepsis patients by clinical outcome and interventions received | eLife | Q1 | Stratificare pazienti con sepsi in base all’evoluzione dei punteggi di rischio | Clustering Spettrale, K-means | 28 cartelle cliniche | Stratificazione in base agli esiti clinici e interventi ricevuti | Identificazione di 4 cluster; supporto nella gestione clinica della sepsi | Sì (scikit-learn) |
# | Using a Method Based on a Modified K-Means Clustering and Mean Shift Segmentation to Reduce File Sizes and Detect Brain Tumors from MRI Images | Wireless Personal Communications | Q2 | Rilevare tumori cerebrali da immagini MRI riducendo la dimensione del file | K-means (modificato), Mean-shift | Immagini MRI | Confronto con K-means e Fuzzy C-means | Metodo proposto più efficiente di K-means e Fuzzy C-means | Sì (scikit-learn) |
# | Open-Box Spectral Clustering: Applications to Medical Image Analysis | IEEE Transactions on Visualization and Computer Graphics | Q1 | Segmentazione delle immagini mediche tramite clustering spettrale | Clustering Spettrale, K-means | Immagini mediche | Gap tra autovettori, interpretabilità dei risultati | Risultati vantaggiosi rispetto a sistemi black-box | Sì (scikit-learn) |
# | Optimizing Patient Stratification in Healthcare: A Comparative Analysis of Clustering Algorithms for EHR Data | International Journal of Computational Intelligence Systems | Q2 | Confrontare 8 algoritmi di clustering su EHR per ottimizzare la stratificazione dei pazienti | K-means, DBSCAN, Gerarchico, Mean-Shift, Affinity-Propagation, Spectral, GMM, SOM | Cartelle cliniche | Accuratezza del clustering, Scalabilità, Robustezza, Interpretabilità | K-means risulta il migliore per robustezza e scalabilità | Sì (scikit-learn) |
# | A comparative analysis of DBSCAN, K-means, and quadratic variation algorithms for automatic identification of swallows from swallowing accelerometry signals | Journal of Computers in Biology and Medicine | Q1 | Confrontare l’efficacia di 3 algoritmi di clustering per identificare deglutizioni da segnali di accelerometria | K-means, DBSCAN, Variazione quadratica | 23 pazienti con difficoltà di deglutizione | Precisione nell’identificazione dei segmenti di deglutizione | DBSCAN più preciso; K-means sensibile al rumore | Sì (scikit-learn) |
# | Identifying clinically important COPD sub-types using data-driven approaches in primary care population based electronic health records | BMC Medical Informatics and Decision Making | Q1 | Scoprire e descrivere sottotipi di BPCO tramite clustering su EHR | K-means, Gerarchico agglomerativo | Cartelle cliniche | Silhouette, Jaccard | K-means più efficiente di Gerarchico; identificazione di 5 cluster distinti | Sì (scikit-learn) |
# | Unsupervised machine learning for the discovery of latent disease clusters and patient subgroups using electronic health records | Journal of Biomedical Informatics | Q1 | Migliorare la qualità del clustering tramite LDA e PDM su dati EHR | K-means, Birch, Gerarchico agglomerativo | Cartelle cliniche | Analisi di sopravvivenza (Kaplan-Meier, Test log-rank), Valore p | K-means più efficiente; LDA stratifica meglio i pazienti, PDM più robusto | Non specificato |
# | Unsupervised Learning to Subphenotype Heart Failure Patients from Electronic Health Records | Artificial Intelligence in Medicine | Q1 | Sottotipizzare pazienti con insufficienza cardiaca tramite clustering su EHR | K-means, Gerarchico agglomerativo | Cartelle cliniche (3.5 milioni di pazienti) | Silhouette, Calinski-Harabasz, Davies-Bouldin | K-means con UMAP più efficiente; k=3 ottimale | Non specificato |
